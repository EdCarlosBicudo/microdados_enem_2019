# %% [markdown]
# <a href="https://colab.research.google.com/github/EdCarlosBicudo/microdados_enem_2019/blob/main/notebooks/2_Prepara%C3%A7%C3%A3o_dos_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Salvando os dados de maneira extensa para facilitar a visualização em outras ferramentas.

# %%
import pandas as pd

# %%
dados = pd.read_csv("/content/drive/MyDrive/dados/microdados_enem.csv", sep=";", index_col=[0])

# %%
dados.head()
# Out:
#   MUNICIPIOR ESISDENCIA UF RESIDENCIA  IDADE  ... COMPUTADOR  INTERNET  MEDIA FINAL
# 3                Palmas            TO   25.0  ...          B         B       475.34
# 4              Contagem            MG   22.0  ...          B         B       639.36
# 5          Rondonópolis            MT   37.0  ...          B         B       649.62
# 6          Paulo Afonso            BA   22.0  ...          A         A       534.98
# 9             São Paulo            SP   17.0  ...          B         B       495.04
#
# [5 rows x 75 columns]

# %%
estado_civil = {0: 'Não informado',
                1: 'Solteiro(a)',
                2: 'Casado(a)/Mora com companheiro(a)',
                3: 'Divorciado(a)/Desquitado(a)/Separado(a)',
                4: 'Viúvo(a)'}

cor = {0: 'Não declarado',
       1: 'Branca',
       2: 'Preta',
       3: 'Parda',
       4: 'Amarela',
       5: 'Indígena'}

nacionalidade = {0: 'Não informado',
                 1: 'Brasileiro(a)',
                 2: 'Brasileiro(a) Naturalizado(a)',
                 3: 'Estrangeiro(a)',
                 4: 'Brasileiro(a) Nato(a), nascido(a) no exterior'}

ensino_medio = {1: 'Já concluí o Ensino Médio',
                2: 'Estou cursando e concluirei o Ensino Médio em 2019',
                3: 'Estou cursando e concluirei o Ensino Médio após 2019',
                4: 'Não concluí e não estou cursando o Ensino Médio'}

tipo_escola = {1: 'Não Respondeu',
               2: 'Pública',
               3: 'Privada',
               4: 'Exterior'}

tipo_ensino = {1: 'Ensino Regular',
               2: 'Educação Especial - Modalidade Substitutiva',
               3: 'Educação de Jovens e Adultos'}

dependencia_administrativa = {1: 'Federal',
                              2: 'Estadual',
                              3: 'Municipal',
                              4: 'Privada'}

localizacao_escola = {1: 'Urbana',
                      2: 'Rural'}

situacao_redacao = {1: 'Sem problemas',
                    2: 'Anulada',
                    3: 'Cópia Texto Motivador',
                    4: 'Em Branco',
                    6: 'Fuga ao tema',
                    7: 'Não atendimento ao tipo textual',
                    8: 'Texto insuficiente',
                    9: 'Parte desconectada'}

serie_estudo = {'A': 'Nunca estudou.',
                'B': 'Não completou a 4ª série/5º ano do Ensino Fundamental.',
                'C': 'Completou a 4ª série/5º ano, mas não completou a 8ª série/9º ano do Ensino Fundamental.',
                'D': 'Completou a 8ª série/9º ano do Ensino Fundamental, mas não completou o Ensino Médio.',
                'E': 'Completou o Ensino Médio, mas não completou a Faculdade.',
                'F': 'Completou a Faculdade, mas não completou a Pós-graduação.',
                'G': 'Completou a Pós-graduação.',
                'H': 'Não sei.'
}

ocupacao_completo = {'A': 'Grupo 1: Lavrador, agricultor sem empregados, bóia fria, criador de animais (gado, porcos, galinhas, ovelhas, cavalos etc.), apicultor, pescador, lenhador, seringueiro, extrativista.',
                     'B': 'Grupo 2: Diarista, empregado doméstico, cuidador de idosos, babá, cozinheiro (em casas particulares), motorista particular, jardineiro, faxineiro de empresas e prédios, vigilante, porteiro, carteiro, office-boy, vendedor, caixa, atendente de loja, auxiliar administrativo, recepcionista, servente de pedreiro, repositor de mercadoria.',
                     'C': 'Grupo 3: Padeiro, cozinheiro industrial ou em restaurantes, sapateiro, costureiro, joalheiro, torneiro mecânico, operador de máquinas, soldador, operário de fábrica, trabalhador da mineração, pedreiro, pintor, eletricista, encanador, motorista, caminhoneiro, taxista.',
                     'D': 'Grupo 4: Professor (de ensino fundamental ou médio, idioma, música, artes etc.), técnico (de enfermagem, contabilidade, eletrônica etc.), policial, militar de baixa patente (soldado, cabo, sargento), corretor de imóveis, supervisor, gerente, mestre de obras, pastor, microempresário (proprietário de empresa com menos de 10 empregados), pequeno comerciante, pequeno proprietário de terras, trabalhador autônomo ou por conta própria.',
                     'E': 'Grupo 5: Médico, engenheiro, dentista, psicólogo, economista, advogado, juiz, promotor, defensor, delegado, tenente, capitão, coronel, professor universitário, diretor em empresas públicas ou privadas, político, proprietário de empresas com mais de 10 empregados.',
                     'F': 'Não sei.'}

ocupacao_resumo = {'A': 'Grupo 1',
                   'B': 'Grupo 2',
                   'C': 'Grupo 3',
                   'D': 'Grupo 4',
                   'E': 'Grupo 5',
                   'F': 'Não sei.'}

renda = {'A': 'Nenhuma renda.',
         'B': 'Até 998,00.',
         'C': 'De 998,01 até 1.497,00.',
         'D': 'De 1.497,01 até 1.996,00.',
         'E': 'De 1.996,01 até 2.495,00.',
         'F': 'De 2.495,01 até 2.994,00.',
         'G': 'De 2.994,01 até 3.992,00.',
         'H': 'De 3.992,01 até 4.990,00.',
         'I': 'De 4.990,01 até 5.988,00.',
         'J': 'De 5.988,01 até 6.986,00.',
         'K': 'De 6.986,01 até 7.984,00.',
         'L': 'De 7.984,01 até 8.982,00.',
         'M': 'De 8.982,01 até 9.980,00.',
         'N': 'De 9.980,01 até 11.976,00.',
         'O': 'De 11.976,01 até 14.970,00.',
         'P': 'De 14.970,01 até 19.960,00.',
         'Q': 'Mais de 19.960,00.'}

empregado = {'A': 'Não.',
             'B': 'Sim, um ou dois dias por semana.',
             'C': 'Sim, três ou quatro dias por semana.',
             'D': 'Sim, pelo menos cinco dias por semana.'}

nao_sim = {0: 'Não',
           1: 'Sim'}

quantidades = {'A': 'Não.',
               'B': 'Sim, uma.',
               'C': 'Sim, duas.',
               'D': 'Sim, três.',
               'E': 'Sim, quatro ou mais.'}

# %%
dados['ESTADO CIVIL'] = dados['ESTADO CIVIL'].map(estado_civil)
dados['COR'] = dados['COR'].map(cor)
dados['NACIONALIDADE'] = dados['NACIONALIDADE'].map(nacionalidade)
dados['CONCLUSAO ENSINO MEDIO'] = dados['CONCLUSAO ENSINO MEDIO'].map(ensino_medio)
dados['TIPO ESCOLA'] = dados['TIPO ESCOLA'].map(tipo_escola)
dados['TIPO ENSINO'] = dados['TIPO ENSINO'].map(tipo_ensino)
dados['TREINAR'] = dados['TREINAR'].map(nao_sim)
dados['DEPENDENCIA ADMINISTRATIVA'] = dados['DEPENDENCIA ADMINISTRATIVA'].map(dependencia_administrativa)
dados['LOCALIZACAO ESCOLA'] = dados['LOCALIZACAO ESCOLA'].map(localizacao_escola)

dados['BAIXA VISAO'] = dados['BAIXA VISAO'].map(nao_sim)
dados['CEGUEIRA'] = dados['CEGUEIRA'].map(nao_sim)
dados['SURDEZ'] = dados['SURDEZ'].map(nao_sim)
dados['DEFICIENCIA AUDITIVA'] = dados['DEFICIENCIA AUDITIVA'].map(nao_sim)
dados['SURDO CEGO'] = dados['SURDO CEGO'].map(nao_sim)
dados['DEFICIENCIA FISICA'] = dados['DEFICIENCIA FISICA'].map(nao_sim)
dados['DEFICIENCIA MENTAL'] = dados['DEFICIENCIA MENTAL'].map(nao_sim)
dados['DEFICT DE ATENCAO'] = dados['DEFICT DE ATENCAO'].map(nao_sim)
dados['DISLEXIA'] = dados['DISLEXIA'].map(nao_sim)
dados['DISCALCULIA'] = dados['DISCALCULIA'].map(nao_sim)
dados['AUTISMO'] = dados['AUTISMO'].map(nao_sim)
dados['VISAO MONOCULAR'] = dados['VISAO MONOCULAR'].map(nao_sim)
dados['OUTRA DEFICIENCIA'] = dados['OUTRA DEFICIENCIA'].map(nao_sim)
dados['GESTANTE'] = dados['GESTANTE'].map(nao_sim)
dados['LACTANTE'] = dados['LACTANTE'].map(nao_sim)
dados['IDOSO'] = dados['IDOSO'].map(nao_sim)
dados['ENTUDA CLASSE HOSPITALAR'] = dados['ENTUDA CLASSE HOSPITALAR'].map(nao_sim)

dados['SITUACAO DAREDACAO'] = dados['SITUACAO DAREDACAO'].map(situacao_redacao)
dados['SERIE ESTUDO PAI'] = dados['SERIE ESTUDO PAI'].map(serie_estudo)
dados['SERIE ESTUDO MAE'] = dados['SERIE ESTUDO MAE'].map(serie_estudo)
dados['OCUPACAO PAI'] = dados['OCUPACAO PAI'].map(ocupacao_resumo)
dados['OCUPACAO MAE'] = dados['OCUPACAO MAE'].map(ocupacao_resumo)
dados['RENDA FAMILIAR'] = dados['RENDA FAMILIAR'].map(renda)
dados['EMPREGADO DOMESTICO'] = dados['EMPREGADO DOMESTICO'].map(empregado)

dados['BANHEIRO'] = dados['BANHEIRO'].map(quantidades)
dados['QUARTOS'] = dados['QUARTOS'].map(quantidades)
dados['CARRO'] = dados['CARRO'].map(quantidades)
dados['MOTOCICLETA'] = dados['MOTOCICLETA'].map(quantidades)
dados['GELADEIRA'] = dados['GELADEIRA'].map(quantidades)
dados['FREEZER'] = dados['FREEZER'].map(quantidades)
dados['MAQUINA DE LAVAR'] = dados['MAQUINA DE LAVAR'].map(quantidades)
dados['MAQUINA DE SECAR'] = dados['MAQUINA DE SECAR'].map(quantidades)
dados['MICRO-ONDAS'] = dados['MICRO-ONDAS'].map(quantidades)
dados['MAQUINA DE LAVAR LOUCA'] = dados['MAQUINA DE LAVAR LOUCA'].map(quantidades)
dados['ASPIRADOR DE PO'] = dados['ASPIRADOR DE PO'].map(quantidades)
dados['TV COLORIDA'] = dados['TV COLORIDA'].map(quantidades)
dados['DVD'] = dados['DVD'].map(quantidades)
dados['TV POR ASSINATURA'] = dados['TV POR ASSINATURA'].map(quantidades)
dados['TELEFONE CELULAR'] = dados['TELEFONE CELULAR'].map(quantidades)
dados['TELEFONE FIXO'] = dados['TELEFONE FIXO'].map(quantidades)
dados['COMPUTADOR'] = dados['COMPUTADOR'].map(quantidades)
dados['INTERNET'] = dados['INTERNET'].map(nao_sim)

# %%
dados.head()
# Out:
#   MUNICIPIOR ESISDENCIA UF RESIDENCIA  IDADE  ... COMPUTADOR INTERNET MEDIA FINAL
# 3                Palmas            TO   25.0  ...  Sim, uma.      NaN      475.34
# 4              Contagem            MG   22.0  ...  Sim, uma.      NaN      639.36
# 5          Rondonópolis            MT   37.0  ...  Sim, uma.      NaN      649.62
# 6          Paulo Afonso            BA   22.0  ...       Não.      NaN      534.98
# 9             São Paulo            SP   17.0  ...  Sim, uma.      NaN      495.04
#
# [5 rows x 75 columns]

# %%
dados.to_csv('microdados_descritos.csv', sep=';', index=False)
